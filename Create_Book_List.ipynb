# %%
"""
99% Invisible Booklist
Credits NLP 
Author: Lindsey Viann Parkinson Last updated: March 16, 2021
Tokenize the credits scraped earlier and extract authors and title
"""

# Packages
import pandas as pd
from tqdm.notebook import tqdm
import re

import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
credits_df = pd.read_csv('author_episodes_16pgs.csv')
desc_col = credits_df["description"]

# %% [markdown]
# ## Creating titles column

# %%
def titles_from_credits(desc_col): 
    book_title = []
    regex_title = r'(?<=<em>)(.*?)(?=<\/em>)' #italics
    for credit in desc_col:  
        if "<em>" in credit:
            book_title.append(re.findall(regex_title,credit))
        else:
            book_title.append(re.findall(r'(?<=author of )(.*?)(?=\;)', credit)) #between "author of" and a ";"
    return book_title


def clean_titles(desc_col):
    regex_title_href = r'(?<=blank">)(.*?)(?=<\/a>)' 
    all_titles=[]
    for titles_list in titles_from_credits(desc_col):
        title2 =[]
        for item in titles_list:
            if "href" in item:
                string = re.findall(regex_title_href, item) #between pieces of hyperlink with title
                title2.append(string)
            else:
                title2.append(item)
        all_titles.append(title2)
    return all_titles

# %%
book_title = clean_titles(desc_col)

# %%
credits_df['book_title'] = book_title

remove_chars = ['[', ']', "'"]
credits_df['book_title'] = credits_df['book_title'].astype(str).str.translate({ord(elem): None for elem in remove_chars} )

credits_df
# Out:
#         date episode_number  title  \
# 0   03.08.21    Episode 434    NaN
# 1   02.16.21    Episode 431    NaN
# 2   02.08.21    Episode 430    NaN
# 3   11.03.20    Episode 420    NaN
# 4   09.22.20    Episode 414    NaN
# ..       ...            ...    ...
# 75  12.16.14    Episode 145    NaN
# 76  12.09.14    Episode 144    NaN
# 77  10.22.14    Episode 137    NaN
# 78  07.29.14    Episode 125    NaN
# 79  04.08.14    Episode 109    NaN
#
#                                          episode_link  \
# 0   https://99percentinvisible.org/episode/artisti...
# 1   https://99percentinvisible.org/episode/12-head...
# 2   https://99percentinvisible.org/episode/the-doo...
# 3   https://99percentinvisible.org/episode/the-los...
# 4   https://99percentinvisible.org/episode/the-add...
# ..                                                ...
# 75  https://99percentinvisible.org/episode/octotho...
# 76  https://99percentinvisible.org/episode/there-i...
# 77  https://99percentinvisible.org/episode/good-br...
# 78  https://99percentinvisible.org/episode/duplite...
# 79   https://99percentinvisible.org/episode/title-tk/
#
#                                      episode_title  \
# 0                                 Artistic License
# 1   12 Heads from the Garden of Perfect Brightness
# 2                                    The Doom Boom
# 3                           The Lost Cities of Geo
# 4                                 The Address Book
# ..                                             ...
# 75                                      Octothorpe
# 76            There Is a Light That Never Goes Out
# 77                                      Good Bread
# 78                                    Duplitecture
# 79                                        Title TK
#
#                                           description  \
# 0   ['Reporter Daniel Ackerman spoke with Rick Jus...
# 1   ['Producer Vivian Le spoke with Ai Weiwei, art...
# 2   ['Host Roman Mars spoke with Bradley Garrett, ...
# 3   ['Producer Vivian Le spoke with David Bohnett,...
# 4   ['Host Roman Mars spoke with Deirdre Mask, aut...
# ..                                                ...
# 75  ['Producer Avery Trufelman spoke with ', <a hr...
# 76  ['This episode was adapted from a piece that '...
# 77  ['99% Invisible wonder boy\xa0Sam Greenspan sp...
# 78  ['Producer Avery Trufelman spoke with Bianca B...
# 79  ['99% Invisible producer Avery Trufelman spoke...
#
#                                            book_title
# 0   “Speaking of Idaho” blog, Taking the Wheel: Wo...
# 1   Never Forget National Humiliation;\xa0, Chines...
# 2                  Bunker: Building for the End Times
# 3   Fallen Glory: The Lives and Deaths of History’...
# 4
# ..                                                ...
# 75  Shady Characters: The Secret Life of Punctuati...
# 76
# 77  White Bread: A Social History of the Store-Bou...
# 78
# 79
#
# [80 rows x 7 columns]

# %% [markdown]
# ## Creating author column

# %%
podcast_staff = ['Roman Mars', 'Chris Berube', 'Emmett FitzGerald', 'Emmett Fitzgerald', 'Delaney Hall', 'Christopher Johnson', 'Sofia Klatzker Miller', 'Sofia Klatzer', 'Kurt Kohlstedt', 'Vivian Le', 'Abby Madan', 'Katie Mingle', 'Sean Real', 'Joe Rosenberg', 'Avery Trufelman']

# %%
# https://stackoverflow.com/questions/20290870/improving-the-extraction-of-human-names-with-nltk


def extract_names(desc_col):
    names = []
    for description in desc_col:          
        #short_desc = str(re.search(r'(^.*?author of)', description)) + ' foo.'
        for sent in nltk.sent_tokenize(description):
            if "author of" in sent:   
                short_sent = str(re.findall(r'(^.*?author of)', description))
                podcast_guests = []
                for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(short_sent))):
                    if hasattr(chunk, 'label'):
                        if chunk.label() == 'PERSON': 
                            name = ' '.join(c[0] for c in chunk.leaves())
                            if name not in podcast_staff: 
                                podcast_guests.append(name)
                names.append(podcast_guests[-1]) if len(podcast_guests) > 0 else names.append('NA')
                break
    return names

# %%
author = extract_names(desc_col)

# %%
credits_df['author'] = author
credits_df
# Out:
#         date episode_number  title  \
# 0   03.08.21    Episode 434    NaN
# 1   02.16.21    Episode 431    NaN
# 2   02.08.21    Episode 430    NaN
# 3   11.03.20    Episode 420    NaN
# 4   09.22.20    Episode 414    NaN
# ..       ...            ...    ...
# 75  12.16.14    Episode 145    NaN
# 76  12.09.14    Episode 144    NaN
# 77  10.22.14    Episode 137    NaN
# 78  07.29.14    Episode 125    NaN
# 79  04.08.14    Episode 109    NaN
#
#                                          episode_link  \
# 0   https://99percentinvisible.org/episode/artisti...
# 1   https://99percentinvisible.org/episode/12-head...
# 2   https://99percentinvisible.org/episode/the-doo...
# 3   https://99percentinvisible.org/episode/the-los...
# 4   https://99percentinvisible.org/episode/the-add...
# ..                                                ...
# 75  https://99percentinvisible.org/episode/octotho...
# 76  https://99percentinvisible.org/episode/there-i...
# 77  https://99percentinvisible.org/episode/good-br...
# 78  https://99percentinvisible.org/episode/duplite...
# 79   https://99percentinvisible.org/episode/title-tk/
#
#                                      episode_title  \
# 0                                 Artistic License
# 1   12 Heads from the Garden of Perfect Brightness
# 2                                    The Doom Boom
# 3                           The Lost Cities of Geo
# 4                                 The Address Book
# ..                                             ...
# 75                                      Octothorpe
# 76            There Is a Light That Never Goes Out
# 77                                      Good Bread
# 78                                    Duplitecture
# 79                                        Title TK
#
#                                           description  \
# 0   ['Reporter Daniel Ackerman spoke with Rick Jus...
# 1   ['Producer Vivian Le spoke with Ai Weiwei, art...
# 2   ['Host Roman Mars spoke with Bradley Garrett, ...
# 3   ['Producer Vivian Le spoke with David Bohnett,...
# 4   ['Host Roman Mars spoke with Deirdre Mask, aut...
# ..                                                ...
# 75  ['Producer Avery Trufelman spoke with ', <a hr...
# 76  ['This episode was adapted from a piece that '...
# 77  ['99% Invisible wonder boy\xa0Sam Greenspan sp...
# 78  ['Producer Avery Trufelman spoke with Bianca B...
# 79  ['99% Invisible producer Avery Trufelman spoke...
#
#                                            book_title               author
# 0   “Speaking of Idaho” blog, Taking the Wheel: Wo...            Rick Just
# 1   Never Forget National Humiliation;\xa0, Chines...           Zheng Wang
# 2                  Bunker: Building for the End Times      Bradley Garrett
# 3   Fallen Glory: The Lives and Deaths of History’...       James Crawford
# 4                                                             Deirdre Mask
# ..                                                ...                  ...
# 75  Shady Characters: The Secret Life of Punctuati...        Keith Houston
# 76                                                                Mooallem
# 77  White Bread: A Social History of the Store-Bou...  Aaron Bobrow-Strain
# 78                                                           Bianca Bosker
# 79                                                                 Monkeys
#
# [80 rows x 8 columns]

# %%
ReadingList = pd.DataFrame([credits_df.book_title, credits_df.author, credits_df.episode_link]).transpose()

pd.set_option("max_rows", None)
pd.set_option('max_colwidth', None)
ReadingList
# Out:
#                                                                                                                                                                                                 book_title  \
# 0                “Speaking of Idaho” blog, Taking the Wheel: Women and the Coming of the Motor Age, Vintage Views along the West Michigan Pike, Mixed Speech: When speech is both private and governmental
# 1                                                                                                         Never Forget National Humiliation;\xa0, Chinese Antiquities: An Introduction to the Art Market.
# 2                                                                                                                                                                       Bunker: Building for the End Times
# 3                                                                                                                                       Fallen Glory: The Lives and Deaths of History’s Greatest Buildings
# 4
# 5                                                                                                                                          "Transgender History: The Roots of Today’s Revolution</span>, "
# 6                                                                                                                                                           How The Post Office Created America: A History
# 7                                                                                                                                                                                   Policing the Open Road
# 8                                                                                                                                                         Heroic: Concrete Architecture and the New Boston
# 9                                                                                                                                                                                                    Wiped
# 10                                                                                        Machines Who Think, The Most Human Human: What Talking With Computers Teaches Us About What It Means To Be Alive
# 11                               Electric Dreamland: Amusement Parks, Movies, and American Modernity, The Strange Case of Dr. Couney: How a Mysterious European Showman Saved Thousands of American Babies
# 12
# 13                                                                                                                                                                                      Football Clichés,
# 14
# 15                                                                                                                                                                                        Delayed Response
# 16
# 52       David Montgomery
# 53             Joe Nocera
# 54       Anya Von Bremzen
# 55       Christoph Ribbat
# 56            Bonnie Tsui
# 57         Eric Zimmerman
# 58                Salcedo
# 59          Anthony Slide
# 60                     NA
# 61           Johnny Gosch
# 62           Paul Robbins
# 63           Adrian Forty
# 64           Julia DeWitt
# 65                     NA
# 66                 Shamos
# 67               Hardwick
# 68        Mary Jo Ignoffo
# 69     David Ewing Duncan
# 70                     NA
# 71           Jared Farmer
# 72                Mr. Met
# 73                  Dazed
# 74            Jill Jonnes
# 75          Keith Houston
# 76               Mooallem
# 77    Aaron Bobrow-Strain
# 78          Bianca Bosker
# 79                Monkeys
#
#                                                                                               episode_link
# 0                                                 https://99percentinvisible.org/episode/artistic-license/
# 1                   https://99percentinvisible.org/episode/12-heads-from-the-garden-of-perfect-brightness/
# 2                                                    https://99percentinvisible.org/episode/the-doom-boom/
# 3                                           https://99percentinvisible.org/episode/the-lost-cities-of-geo/
# 4                                                 https://99percentinvisible.org/episode/the-address-book/
# 5                                         https://99percentinvisible.org/episode/where-do-we-go-from-here/
# 6                                           https://99percentinvisible.org/episode/the-revolutionary-post/
# 7                                           https://99percentinvisible.org/episode/policing-the-open-road/
# 8                                 https://99percentinvisible.org/episode/the-smell-of-concrete-after-rain/
# 9                                                         https://99percentinvisible.org/episode/wipe-out/
# 10                                                https://99percentinvisible.org/episode/the-eliza-effect/
# 11                                                 https://99percentinvisible.org/episode/the-infantorium/
# 12                                   https://99percentinvisible.org/episode/great-bitter-lake-association/
# 13                                                  https://99percentinvisible.org/episode/unsure-footing/
# 14                                          https://99percentinvisible.org/episode/the-help-yourself-city/
# 15                                               https://99percentinvisible.org/episode/wait-wait-tell-me/
# 16                                            https://99percentinvisible.org/episode/all-rings-considered/
# 17                                                 https://99percentinvisible.org/episode/depave-paradise/
# 18                                                  https://99percentinvisible.org/episode/froebels-gifts/
# 19                                          https://99percentinvisible.org/episode/palaces-for-the-people/
# 20                                               https://99percentinvisible.org/episode/the-known-unknown/
# 21                                                  https://99percentinvisible.org/episode/national-sword/
# 22                                       https://99percentinvisible.org/episode/the-secret-lives-of-color/
# 23                                   https://99percentinvisible.org/episode/the-worst-way-to-start-a-city/
# 24                                 https://99percentinvisible.org/episode/the-house-that-came-in-the-mail/
# 25                                                 https://99percentinvisible.org/episode/the-first-straw/
# 26                                                https://99percentinvisible.org/episode/double-standards/
# 27                                           https://99percentinvisible.org/episode/the-shipping-forecast/
# 28                                                     https://99percentinvisible.org/episode/interrobang/
# 29                                                   https://99percentinvisible.org/episode/right-to-roam/
# 30                                                  https://99percentinvisible.org/episode/immobile-homes/
# 31                                                      https://99percentinvisible.org/episode/fordlandia/
# 32                                                 https://99percentinvisible.org/episode/thermal-delight/
# 33                                                  https://99percentinvisible.org/episode/oyster-tecture/
# 34                                                   https://99percentinvisible.org/episode/half-measures/
# 35                                              https://99percentinvisible.org/episode/great-dismal-swamp/
# 36                                            https://99percentinvisible.org/episode/repackaging-the-pill/
# 37                                                       https://99percentinvisible.org/episode/mexico-68/
# 38                                       https://99percentinvisible.org/episode/squatters-lower-east-side/
# 39                                                      https://99percentinvisible.org/episode/new-jersey/
# 40                                                https://99percentinvisible.org/episode/atom-garden-eden/
# 41                                            https://99percentinvisible.org/episode/usonia-the-beautiful/
# 42                                                    https://99percentinvisible.org/episode/plat-of-zion/
# 43                        https://99percentinvisible.org/episode/reverb-evolution-architectural-acoustics/
# 44                                                https://99percentinvisible.org/episode/making-up-ground/
# 45  https://99percentinvisible.org/episode/public-works-rethinking-americas-transportation-infrastructure/
# 46                                                      https://99percentinvisible.org/episode/on-average/
# 47                                  https://99percentinvisible.org/episode/photo-credit-negatives-bauhaus/
# 48                                        https://99percentinvisible.org/episode/the-mind-of-an-architect/
# 49                                                           https://99percentinvisible.org/episode/h-day/
# 50                                                  https://99percentinvisible.org/episode/vox-ex-machina/
# 51                                                   https://99percentinvisible.org/episode/frozen-assets/
# 52                                                     https://99percentinvisible.org/episode/fish-cannon/
# 53                                                 https://99percentinvisible.org/episode/the-fresno-drop/
# 54                                                      https://99percentinvisible.org/episode/bone-music/
# 55                                                    https://99percentinvisible.org/episode/tube-benders/
# 56                                            https://99percentinvisible.org/episode/pagodas-dragon-gates/
# 57                                              https://99percentinvisible.org/episode/the-landlords-game/
# 58                                                   https://99percentinvisible.org/episode/war-and-pizza/
# 59                                                   https://99percentinvisible.org/episode/atmospherians/
# 60                                     https://99percentinvisible.org/episode/a-sweet-surprise-awaits-you/
# 61                                                https://99percentinvisible.org/episode/milk-carton-kids/
# 62                                                      https://99percentinvisible.org/episode/lawn-order/
# 63                                            https://99percentinvisible.org/episode/hard-to-love-a-brute/
# 64                                            https://99percentinvisible.org/episode/from-the-sea-freedom/
# 65                                            https://99percentinvisible.org/episode/viva-la-arquitectura/
# 66                                          https://99percentinvisible.org/episode/the-post-billiards-age/
# 67                                                https://99percentinvisible.org/episode/the-gruen-effect/
# 68                                                   https://99percentinvisible.org/episode/mystery-house/
# 69                                                    https://99percentinvisible.org/episode/the-calendar/
# 70                                                     https://99percentinvisible.org/episode/devils-rope/
# 71                                                    https://99percentinvisible.org/episode/palm-reading/
# 72                                                     https://99percentinvisible.org/episode/la-mascotte/
# 73                                             https://99percentinvisible.org/episode/under-the-moonlight/
# 74                                              https://99percentinvisible.org/episode/penn-station-sucks/
# 75                                                      https://99percentinvisible.org/episode/octothorpe/
# 76                            https://99percentinvisible.org/episode/there-is-a-light-that-never-goes-out/
# 77                                                      https://99percentinvisible.org/episode/good-bread/
# 78                                                    https://99percentinvisible.org/episode/duplitecture/
# 79                                                        https://99percentinvisible.org/episode/title-tk/
