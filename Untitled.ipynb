# %%
"""
99% Invisible Booklist
Author: Lindsey Viann Parkinson Last updated: February 11, 2021
Scrapes the 99% Invisible podcast website, 99pi.org, and pulls information from the episodes that interview an author. Specifically honing in on "author of" in the episode description
"""
# Packages
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm # this is a fancy progress bar! works on jupyter notebook
from time import sleep
from datetime import datetime



#url = 'https://99percentinvisible.org/episodes/?view_option=list'


def get_episodes(url):
    """
    Returns episode information from one page of 99pi episodes list
    url = 99pi url of episode list
    """

    print(f"^ scraping basic episode information. 20 episodes per page")
    response = requests.get(url, timeout = 2)
    print(f"Testing link of each page. 200 is good: {response.status_code}")

    soup = BeautifulSoup(response.content, "html.parser")

    cols = ["date", "episode_number", "title", "episode_link"]
    episodes_onepage = pd.DataFrame(columns = cols)

    all_episodes = soup.find_all("article", class_ = "list-block post episode")
    for episode in all_episodes:
        
        episode_link = episode.find("h3", {"class": "list-title"}).find("a").get("href")
        
        span_list = []
        for span in episode.find_all("span"):
            span_list.append(span.text) 
        
        date = span_list[3]

        episode_number = span_list[2]

        title = episode.find("a",{"class": "play"}).get("title")

        
        episodes_onepage = episodes_onepage.append(
            {
                "date": date,
                "episode_number": episode_number,
                "title": title,
                "episode_link": episode_link
            },
            ignore_index=True,
        )
        
    return episodes_onepage


#Scrape all pages or set page limit
#all_pages = soup.find("a",{"class": "page-numbers"}).find_next_siblings("a")[-1].get("data-page-number")
#max_pages = 4


def get_all_episodes(max_pages):
    link_first_part = "https://99percentinvisible.org/episodes/page/"
    link_2_part = "/?view_option=list"
    
    cols = ["date", "episode_number", "title", "episode_link"]
    episodes_multipage = pd.DataFrame(columns = cols)
    
    for page in tqdm(range(1, int(max_pages) + 1)):
        
        url = (
            link_first_part
            + str(page)
            + link_2_part
        )
        episodes_multipage = episodes_multipage.append(get_episodes(url), ignore_index=True)# = get_episodes(url).append(episodes_onepage, ignore_index=True)
        sleep(0.6) # to keep up with human speed we need to slow down program
    
    return episodes_multipage

# episode description extracted from each link
# appended to existing dataframe
def get_description(max_pages):
    """
    max_pages is the number of 99pi website episode list pages to scrape
    
    get_description calls 'get_all_episodes' which calls 'get_episodes'
    
    episode description extracted from each link
    appended to dataframe from get_all_episodes
    """
    df = get_all_episodes(max_pages)
    description = []
    print(f"Pulling every episode's description:")
    for link in tqdm(df["episode_link"]):
        
        response2 = requests.get(link, timeout=15)
        soup2 = BeautifulSoup(response2.content, "html.parser")
        
        try: 
            footer = soup2.find("footer")
            desc = footer.find("div", {"class": "credit"}).find("p").contents
            description.append(desc)
        except:
            description.append('NA')
    
    df["description"] = description
    
    return df
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
#
# Pulling every episode's description:
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))
#             date episode_number  \
# 0       02.23.21    Episode 432
# 1       02.16.21    Episode 431
# 2       02.08.21    Episode 430
# 3       02.02.21    Episode 429
# 4       01.26.21    Episode 428
# 5       01.19.21    Episode 427
# 6       01.12.21    Episode 426
# 7       12.22.20    Episode 425
# 8   Add to Queue       12.18.20
# 9   Add to Queue       12.15.20
# 10  Add to Queue       12.11.20
# 11  Add to Queue       12.08.20
# 12  Add to Queue       12.04.20
# 13  Add to Queue       12.01.20
# 14  Add to Queue       12.01.20
# 15      11.24.20    Episode 424
# 16      11.20.20    Episode 423
# 17      11.17.20    Episode 422
# 18      11.09.20    Episode 421
# 19      11.03.20    Episode 420
# 20      10.27.20    Episode 419
# 21      10.20.20    Episode 418
# 22  Add to Queue       10.19.20
# 23      10.13.20    Episode 417
# 24      10.06.20    Episode 416
# 25      09.29.20    Episode 415
# 26      09.22.20    Episode 414
# 27      09.15.20    Episode 413
# 28      09.08.20    Episode 412
# 29      09.01.20    Episode 411
#
#                                              title  \
# 0                The Batman and the Bridge Builder
# 1   12 Heads from the Garden of Perfect Brightness
# 2                                    The Doom Boom
# 3                                 Stuccoed in Time
# 4                               Beneath the Skyway
# 5                          Mini-Stories: Volume 11
# 6                          Mini-Stories: Volume 10
# 7                           Mini-Stories: Volume 9
# 8                           Roman Mars on Bullseye
# 9                       Chapter 5: Housing Finally
# 10                             Chapter 4: The List
# 11                        Chapter 3: Housing First
# 12                          Chapter 2: The Hotline
# 13                              Chapter 1: Tulicia
# 14                     According to Need: Prologue
# 15                               The Great Indoors
# 16                                   Sean Exploder
# 17                           In The Unlikely Event
# 18                          You’ve Got Enron Mail!
# 19                          The Lost Cities of Geo
# 20                                     Take a Walk
# 21                                   Sign Stealing
# 22                          The Next Billion Users
# 23                            For the Love of Peat
# 24                Exploring The 99% Invisible City
# 25                                Goodnight Nobody
# 26                                The Address Book
# 27                  Ubiquitous Icons: Highways 101
# 28                       Where Do We Go From Here?
# 29                                 Podcast Episode
#
#                                          episode_link  \
# 0   https://99percentinvisible.org/episode/the-bat...
# 1   https://99percentinvisible.org/episode/12-head...
# 2   https://99percentinvisible.org/episode/the-doo...
# 3   https://99percentinvisible.org/episode/stuccoe...
# 4   https://99percentinvisible.org/episode/beneath...
# 5   https://99percentinvisible.org/episode/mini-st...
# 6   https://99percentinvisible.org/episode/mini-st...
# 7   https://99percentinvisible.org/episode/mini-st...
# 8   https://99percentinvisible.org/episode/roman-m...
# 9   https://99percentinvisible.org/episode/accordi...
# 10  https://99percentinvisible.org/episode/accordi...
# 11  https://99percentinvisible.org/episode/accordi...
# 12  https://99percentinvisible.org/episode/accordi...
# 13  https://99percentinvisible.org/episode/accordi...
# 14  https://99percentinvisible.org/episode/accordi...
# 15  https://99percentinvisible.org/episode/the-gre...
# 16  https://99percentinvisible.org/episode/sean-ex...
# 17  https://99percentinvisible.org/episode/in-the-...
# 18  https://99percentinvisible.org/episode/youve-g...
# 19  https://99percentinvisible.org/episode/the-los...
# 20  https://99percentinvisible.org/episode/take-a-...
# 21  https://99percentinvisible.org/episode/sign-st...
# 22  https://99percentinvisible.org/episode/the-nex...
# 23  https://99percentinvisible.org/episode/for-the...
# 24  https://99percentinvisible.org/episode/explori...
# 25  https://99percentinvisible.org/episode/goodnig...
# 26  https://99percentinvisible.org/episode/the-add...
# 27  https://99percentinvisible.org/episode/ubiquit...
# 28  https://99percentinvisible.org/episode/where-d...
# 29  https://99percentinvisible.org/episode/podcast...
#
#                                           description
# 0   [Producer Emmett FitzGerald spoke with Merlin ...
# 1   [Producer Vivian Le spoke with Ai Weiwei, arti...
# 2   [Host Roman Mars spoke with Bradley Garrett, a...
# 3   [Delaney Hall spoke with architect Trey Jordan...
# 4   [Reporter Katie Thornton spoke with Bill Linde...
# 5                                                  NA
# 6                                                  NA
# 7                                                  NA
# 8                                                  NA
# 9   [According to Need was produced by Katie Mingl...
# 10  [This chapter of , [According to Need],  was p...
# 11  [According to Need was produced by Katie Mingl...
# 12  [According to Need was produced by Katie Mingl...
# 13  [According to Need was produced by Katie Mingl...
# 14  [According to Need was produced by Katie Mingl...
# 15  [Host Roman Mars spoke with author Emily Anthe...
# 16  [Producer Emmett FitzGerald spoke with Sean Re...
# 17  [Reporter Mo , [LaBorde spoke with ], Larry Br...
# 18  [Produced by Dan Bobkoff, Amy Pedulla, Jennife...
# 19  [Producer Vivian Le spoke with David Bohnett, ...
# 20                                                 NA
# 21  [THE EDGE is presented by Prologue Projects in...
# 22                                                 NA
# 23  [Producer Emmett FitzGerald spoke with , [Rich...
# 24                                                 NA
# 25                                                 NA
# 26  [Host Roman Mars spoke with Deirdre Mask, auth...
# 27                                                 NA
# 28  [Reporter Sandy Allen spoke with Joel Sanders,...
# 29  [Producer Chris Berube spoke with , [Terry O’R...

# %%
url = 'https://99percentinvisible.org/episodes/?view_option=list'


def total_episode_pages(url): 
    response = requests.get(url, timeout = 2)
    soup = BeautifulSoup(response.content, "html.parser")

    total_pages = soup.find("a",{"class": "page-numbers"}).find_next_siblings("a")[-1].get("data-page-number")
    return f"99% Invisible has {total_pages} pages of episodes"
    
total_episode_pages(url)
# Out:
# '99% Invisible has 16 pages of episodes'

# %%
def author_episodes(max_pages):
    df_allepisodes = get_description(max_pages)

    df_credits = df_allepisodes[df_allepisodes.description != 'NA']
    df_credits['description'] = df_credits['description'].astype(str)
    df_authors = df_credits[df_credits['description'].str.contains("author of")].reset_index(drop=True)

    return df_authors

# %%
author_episodes(8)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
# ^ scraping basic episode information. 20 episodes per page
# Testing link of each page. 200 is good: 200
#
# Pulling every episode's description:
# HBox(children=(FloatProgress(value=0.0, max=240.0), HTML(value='')))
# <ipython-input-58-3351fb562e92>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_credits['description'] = df_credits['description'].astype(str)
#         date episode_number  \
# 0   02.16.21    Episode 431
# 1   02.08.21    Episode 430
# 2   11.03.20    Episode 420
# 3   09.22.20    Episode 414
# 4   09.08.20    Episode 412
# 5   08.25.20    Episode 244
# 6   08.11.20    Episode 410
# 7   04.28.20    Episode 400
# 8   04.07.20    Episode 397
# 9   12.10.19    Episode 382
# 10  12.03.19    Episode 381
# 11  10.29.19    Episode 376
# 12  10.15.19    Episode 374
# 13  09.30.19    Episode 372
# 14  09.03.19    Episode 369
# 15  08.27.19    Episode 368
# 16  05.28.19    Episode 355
# 17  04.09.19    Episode 349
# 18  03.19.19    Episode 346
# 19  03.05.19    Episode 344
# 20  02.19.19    Episode 342
# 21  02.12.19    Episode 341
# 22  02.05.19    Episode 340
# 23  10.16.18    Episode 325
# 24  09.11.18    Episode 323
# 25  09.04.18    Episode 322
# 26  08.28.18    Episode 321
# 27  07.24.18    Episode 316
# 28  07.10.18    Episode 314
# 29  06.26.18    Episode 313
# 30  05.15.18    Episode 307
# 31  03.06.18    Episode 298
# 32  01.16.18    Episode 291
# 33  10.31.17    Episode 282
# 34  10.17.17    Episode 280
# 35  08.15.17    Episode 271
# 36  07.10.17    Episode 266
# 37  06.27.17    Episode 264
# 38  05.30.17    Episode 261
# 39  05.23.17    Episode 260
# 40  02.21.17    Episode 248
# 41  02.14.17    Episode 247
# 42  12.12.16    Episode 240
# 43  11.14.16    Episode 236
# 44  09.13.16    Episode 228
# 45  09.06.16    Episode 227
# 46  08.23.16    Episode 226
# 47  08.16.16    Episode 225
# 48  07.12.16    Episode 220
#
#                                                 title  \
# 0      12 Heads from the Garden of Perfect Brightness
# 1                                       The Doom Boom
# 2                              The Lost Cities of Geo
# 3                                    The Address Book
# 4                           Where Do We Go From Here?
# 5                              The Revolutionary Post
# 6                              Policing the Open Road
# 7                    The Smell of Concrete After Rain
# 8                                            Wipe Out
# 9                                    The ELIZA Effect
# 10                                    The Infantorium
# 11                      Great Bitter Lake Association
# 12                                     Unsure Footing
# 13                             The Help-Yourself City
# 14                                 Wait Wait…Tell Me!
# 15                               All Rings Considered
# 16                                    Depave Paradise
# 17                                    Froebel’s Gifts
# 18                             Palaces for the People
# 19                                  The Known Unknown
# 20                               Beneath the Ballpark
# 21                                     National Sword
# 22                          The Secret Lives of Color
# 23                      The Worst Way to Start a City
# 24                    The House that Came in the Mail
# 25                                    The First Straw
# 26                                   Double Standards
# 27                              The Shipping Forecast
# 28                                        Interrobang
# 29                                      Right to Roam
# 30                                     Immobile Homes
# 31                                         Fordlandia
# 32                                    Thermal Delight
# 33                                     Oyster-tecture
# 34                                      Half Measures
# 35                             The Great Dismal Swamp
# 36                               Repackaging the Pill
# 37                                          Mexico 68
# 38                   Squatters of the Lower East Side
# 39                                         New Jersey
# 40                         Atom in the Garden of Eden
# 41                               Usonia the Beautiful
# 42                                       Plat of Zion
# 43   Reverb: The Evolution of Architectural Acoustics
# 44                                   Making Up Ground
# 45  Public Works: Rethinking America’s Transportat...
# 46                                         On Average
# 47             Photo Credit: Negatives of the Bauhaus
# 48                           The Mind of an Architect
#
#                                          episode_link  \
# 0   https://99percentinvisible.org/episode/12-head...
# 1   https://99percentinvisible.org/episode/the-doo...
# 2   https://99percentinvisible.org/episode/the-los...
# 3   https://99percentinvisible.org/episode/the-add...
# 4   https://99percentinvisible.org/episode/where-d...
# 5   https://99percentinvisible.org/episode/the-rev...
# 6   https://99percentinvisible.org/episode/policin...
# 7   https://99percentinvisible.org/episode/the-sme...
# 8    https://99percentinvisible.org/episode/wipe-out/
# 9   https://99percentinvisible.org/episode/the-eli...
# 10  https://99percentinvisible.org/episode/the-inf...
# 11  https://99percentinvisible.org/episode/great-b...
# 12  https://99percentinvisible.org/episode/unsure-...
# 13  https://99percentinvisible.org/episode/the-hel...
# 14  https://99percentinvisible.org/episode/wait-wa...
# 15  https://99percentinvisible.org/episode/all-rin...
# 16  https://99percentinvisible.org/episode/depave-...
# 17  https://99percentinvisible.org/episode/froebel...
# 18  https://99percentinvisible.org/episode/palaces...
# 19  https://99percentinvisible.org/episode/the-kno...
# 20  https://99percentinvisible.org/episode/beneath...
# 21  https://99percentinvisible.org/episode/nationa...
# 22  https://99percentinvisible.org/episode/the-sec...
# 23  https://99percentinvisible.org/episode/the-wor...
# 24  https://99percentinvisible.org/episode/the-hou...
# 25  https://99percentinvisible.org/episode/the-fir...
# 26  https://99percentinvisible.org/episode/double-...
# 27  https://99percentinvisible.org/episode/the-shi...
# 28  https://99percentinvisible.org/episode/interro...
# 29  https://99percentinvisible.org/episode/right-t...
# 30  https://99percentinvisible.org/episode/immobil...
# 31  https://99percentinvisible.org/episode/fordlan...
# 32  https://99percentinvisible.org/episode/thermal...
# 33  https://99percentinvisible.org/episode/oyster-...
# 34  https://99percentinvisible.org/episode/half-me...
# 35  https://99percentinvisible.org/episode/great-d...
# 36  https://99percentinvisible.org/episode/repacka...
# 37  https://99percentinvisible.org/episode/mexico-68/
# 38  https://99percentinvisible.org/episode/squatte...
# 39  https://99percentinvisible.org/episode/new-jer...
# 40  https://99percentinvisible.org/episode/atom-ga...
# 41  https://99percentinvisible.org/episode/usonia-...
# 42  https://99percentinvisible.org/episode/plat-of...
# 43  https://99percentinvisible.org/episode/reverb-...
# 44  https://99percentinvisible.org/episode/making-...
# 45  https://99percentinvisible.org/episode/public-...
# 46  https://99percentinvisible.org/episode/on-aver...
# 47  https://99percentinvisible.org/episode/photo-c...
# 48  https://99percentinvisible.org/episode/the-min...
#
#                                           description
# 0   ['Producer Vivian Le spoke with Ai Weiwei, art...
# 1   ['Host Roman Mars spoke with Bradley Garrett, ...
# 2   ['Producer Vivian Le spoke with David Bohnett,...
# 3   ['Host Roman Mars spoke with Deirdre Mask, aut...
# 4   ['Reporter Sandy Allen spoke with Joel Sanders...
# 5   ['Host Roman Mars and producer Katie Mingle sp...
# 6   ['Host Roman Mars spoke with Sarah Seo, author...
# 7   ['Producer Avery Trufelman spoke with Adrian F...
# 8   ['Reporter Stephanie Joyce spoke with Ron Blum...
# 9   ['Producer Delaney Hall spoke with  Pamela McC...
# 10  ['Reporter Katie Thornton has posted many arch...
# 11  ['Producer Vivian Le spoke with Cath Senker, a...
# 12  ['Producer Emmett FitzGerald spoke with Adam H...
# 13  ['Host Roman Mars spoke with Gordon C.C. Dougl...
# 14  ['Reporter Angus Chen spoke with Brad Myers, p...
# 15  ['Reporter James T. Green spoke with Arthur Ro...
# 16  ['Producer Emmett FitzGerald spoke with landsc...
# 17  ['Producer Kurt Kohlstedt spoke with Norman Br...
# 18  ['Host Roman Mars spoke with Eric Klinenberg, ...
# 19  ['Producer Joe Rosenberg spoke with Robert Poo...
# 20  ['Producer Vivian Le spoke with Carol Jacques ...
# 21  ['This episode featured the voices of Kate O’N...
# 22  ['Host Roman Mars spoke with Kassia St. Clair,...
# 23  ['Host and producer Roman Mars spoke with Sam ...
# 24  ['Producer Joe Rosenberg spoke with', <a href=...
# 25  ['Host Roman Mars interviewed\xa0', <a href="h...
# 26  ['Producer Vivian Le spoke with John DiMoia, p...
# 27  ['Producer Emmett FitzGerald and host Roman Ma...
# 28  ['Producer Joe Rosenberg spoke with\xa0Keith H...
# 29  ['Producer Katie Mingle spoke with her dad, ',...
# 30  ['Producer ', <a href="https://99percentinvisi...
# 31  ['Roger Weber, host of a podcast called ', <a ...
# 32  [<a href="https://99percentinvisible.org/autho...
# 33  ['Producer Emmett FitzGerarld spoke with\xa0Pa...
# 34  ['Reporter ', <a href="http://joelwerner.com/"...
# 35  ['Producer Sharif Youssef spoke with Eric Shep...
# 36  ['Reporter\xa0', <a href="http://www.lilachern...
# 37  ['Producers\xa0Claire Mullen and Avery Trufelm...
# 38  ['Producer Delaney Hall spoke with ', <a href=...
# 39  ['Reporter Joe Sykes spoke with BBC journalist...
# 40  [<span style="font-weight: 400;">Producer Shar...
# 41  ['Producer Avery Trufelman spoke with Roland R...
# 42  ['Producer Sam Greenspan spoke with ', <a href...
# 43  ['Producer ', <a href="https://99percentinvisi...
# 44  ['Reporter Emmett Fitzgerald spoke with\xa0', ...
# 45  ['Host and producer Roman Mars spoke with\xa0'...
# 46  ['Producer Avery Trufelman spoke with\xa0', <a...
# 47  ['Producer ', <a href="https://99percentinvisi...
# 48  ['Producer ', <a href="https://99percentinvisi...
